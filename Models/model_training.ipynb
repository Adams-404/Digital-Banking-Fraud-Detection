# %% [markdown]
# # Model Development
# **Digital Banking Fraud Detection Project**
#
# This notebook trains four binary classification algorithms (Logistic Regression, Decision Tree, Random Forest, and XGBoost) on the balanced training dataset, and saves the trained models.

# %%
import os
import pickle
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# ### Load the Processed Training Set

# %%
X_train = pd.read_csv('../Models/X_train.csv')
y_train = pd.read_csv('../Models/y_train.csv').values.ravel()
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### 1. Logistic Regression

# %%
print("Training Logistic Regression...")
lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train)
with open('../Models/logistic_regression.pkl', 'wb') as f:
    pickle.dump(lr, f)

# %% [markdown]
# #### 2. Decision Tree

# %%
print("Training Decision Tree...")
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
with open('../Models/decision_tree.pkl', 'wb') as f:
    pickle.dump(dt, f)

# %% [markdown]
# #### 3. Random Forest

# %%
print("Training Random Forest (this might take a moment)...")
rf = RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=42)
rf.fit(X_train, y_train)
with open('../Models/random_forest.pkl', 'wb') as f:
    pickle.dump(rf, f)

# %% [markdown]
# #### 4. XGBoost

# %%
print("Training XGBoost...")
xgb = XGBClassifier(eval_metric='logloss', n_jobs=-1, random_state=42)
xgb.fit(X_train, y_train)
with open('../Models/xgboost.pkl', 'wb') as f:
    pickle.dump(xgb, f)
print("All models trained and saved successfully!")
